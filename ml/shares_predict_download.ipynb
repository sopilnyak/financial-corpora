# %% [markdown]
# ## Извлекаем тикеры из новостей

# %%
# !unzip -q data_fresh.zip -d data_fr

# %%
# !pip install iexfinance
# Out:
# Requirement already satisfied: iexfinance in /usr/local/lib/python3.6/dist-packages (0.3.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from iexfinance) (2.18.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from iexfinance) (0.22.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->iexfinance) (3.0.4)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->iexfinance) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->iexfinance) (2018.10.15)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->iexfinance) (2.6)
# Requirement already satisfied: python-dateutil>=2 in /usr/local/lib/python3.6/dist-packages (from pandas->iexfinance) (2.5.3)
# Requirement already satisfied: pytz>=2011k in /usr/local/lib/python3.6/dist-packages (from pandas->iexfinance) (2018.7)
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from pandas->iexfinance) (1.14.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2->pandas->iexfinance) (1.11.0)

# %%
from tqdm import tqdm
import re
import os
import pandas as pd
from datetime import datetime, timedelta

import iexfinance as fn

# %%
# Прочитаем новости из файлов

directory = 'data_fr/data_fresh'
files = os.listdir(directory)

articles = []
timestamps = []  # Из всей метаинформации нам интересны только таймстампы
token_filenames = []

for file in tqdm(files[:800]):
    
    if file.endswith(".csv"):
        timestamps.append(pd.read_csv(os.path.join(directory, file))['timestamp'][0])
        try:
            with open(os.path.join(directory, file.replace('.csv', '.txt')), 'r') as f:
                articles.append(f.read().replace('\n', ' '))
        except FileNotFoundError:
            timestamps = timestamps[:-1]

assert len(articles) == len(timestamps)
# Out:
#   0%|          | 0/800 [00:00<?, ?it/s]
#
#
#  26%|██▌       | 206/800 [00:00<00:00, 2049.68it/s]
#
#
#  59%|█████▉    | 474/800 [00:00<00:00, 2198.82it/s]
#
#
#  92%|█████████▏| 736/800 [00:00<00:00, 2296.02it/s]
#
#
# 100%|██████████| 800/800 [00:00<00:00, 2313.15it/s]

# %%
# Извлечем и отфильтруем возможные тикеры

max_ticker_length = 15
stopword = 'GMT'

tickers = []
for article in articles:
    
    possible_tickers = re.findall(r"\(([^\)]+)\)", article)
    possible_tickers = list(filter(
        lambda x: len(x) <= max_ticker_length and 
        ':' in x and  # Будем брать только тикеры на биржах, а не индексы, например
        stopword not in x,  # Попадаются выражения вида 08:00 GMT
        possible_tickers))
    
    tickers.append(possible_tickers)
    
assert len(tickers) == len(articles)

# %%
# Убираем новости, для которых нет тикеров

def remove_empty_tickers(articles, timestamps, tickers, targets=None):
    filtered_articles = []
    filtered_timestamps = []
    filtered_tickers = []
    filtered_targets = []
    for i, article in enumerate(articles):
        if len(tickers[i]) > 0:
            filtered_articles.append(article)
            filtered_timestamps.append(timestamps[i])
            filtered_tickers.append(tickers[i])
            
            if targets:
                filtered_targets.append(targets[i])

    assert len(filtered_articles) == len(filtered_timestamps) == len(filtered_tickers)
    return filtered_articles, filtered_timestamps, filtered_tickers, filtered_targets

# %%
articles, timestamps, tickers, _ = remove_empty_tickers(articles, timestamps, tickers)
print(len(articles))
# Out:
# 167

# %% [markdown]
# ## Собираем датасет с динамикой стоимости акций

# %%
time = datetime.strptime("15:22", '%H:%M')
day = datetime.strptime("2018-11-28", '%Y-%m-%d')

# И timestamp, и данные IEX в ET timezone

if time < datetime.strptime("09:30", '%H:%M'):
    time = datetime.strptime("09:30", '%H:%M')
    day += timedelta(days=1)
    time = datetime.strptime("09:30", '%H:%M')
    
chart = fn.stocks.get_historical_intraday("AAPL", day)

price = None
for point in chart:
    if point['minute'] == datetime.strftime(time, '%H:%M'):
        price = point['average']
        
price
# Out:
# 179.719

# %%
neutral_threshold = 0.001
delay_mins = 1  # Чтобы не совершать сделку прямо в момент выхода новости, введем задержку

filtered_tickers = []
prices = []
for i, timestamp in tqdm(enumerate(timestamps)):
    
    day_string = timestamp.split(' ')[0]
    day = datetime.strptime(day_string, '%Y-%m-%d')
    
    # И timestamp, и данные IEX в ET timezone
    time = datetime.strptime(timestamp.split(' ')[1], '%H:%M')
    if time < datetime.strptime("09:30", '%H:%M'):
        time = datetime.strptime("09:30", '%H:%M')
    if time > datetime.strptime("16:00", '%H:%M'):
        day += timedelta(days=1)
        time = datetime.strptime("09:30", '%H:%M')
        
    time += timedelta(minutes=delay_mins)
    time = datetime.strftime(time, '%H:%M')
    
    current_filtered_tickers = []
    article_prices = []
    for ticker in tickers[i]:
        short_ticker = ticker.split(':')[-1]  # E.g. NASDAQ:AAPL -> AAPL
        
        try:
            chart = fn.stocks.get_historical_intraday(symbol=short_ticker, date=day)

            price = None
            for point in chart:
                if point['minute'] == time:
                    price = point['average']
                    break

            article_prices.append(price)
            
            current_filtered_tickers.append(ticker)
                
        except fn.utils.exceptions.IEXQueryError:
            pass  # Не нашли нужный тикер
            
        except KeyError:
            pass  # Может вернуться пустой dict в запросе
            
    filtered_tickers.append(current_filtered_tickers)
    prices.append(article_prices)
# Out:
# 0it [00:00, ?it/s]
#
#
# 1it [00:02,  2.73s/it]
#
#
# 2it [00:23,  8.00s/it]
#
#
# 3it [00:25,  6.33s/it]
#
#
# 4it [00:42,  9.40s/it]
#
#
# 5it [00:50,  9.22s/it]
#
#
# 6it [00:51,  6.74s/it]
#
#
# 7it [00:52,  4.80s/it]
#
#
# 8it [00:52,  3.43s/it]
#
#
# 9it [00:53,  2.67s/it]
#
#
# 10it [00:55,  2.41s/it]
#
#
# 11it [01:07,  5.53s/it]
#
#
# 12it [01:28,  9.97s/it]
#
#
# 13it [01:30,  7.83s/it]
#
#
# 14it [01:42,  9.06s/it]
#
#
# 15it [01:48,  8.00s/it]
#
#
# 16it [02:03, 10.24s/it]
#
#
# 17it [02:08,  8.64s/it]
#
#
# 18it [02:21,  9.80s/it]
#
#
# 19it [02:26,  8.42s/it]
#
#
# 20it [02:28,  6.57s/it]
#
#
# 21it [02:29,  4.76s/it]
#
#
# 22it [02:29,  3.39s/it]
#
#
# 23it [02:29,  2.52s/it]
#
#
# 24it [03:00, 11.03s/it]
#
#
# 25it [03:18, 13.06s/it]
#
#
# 26it [03:18,  9.22s/it]
#
#
# 27it [03:23,  7.89s/it]
#
#
# 28it [03:23,  5.60s/it]
#
#
# 29it [03:38,  8.22s/it]
#
#
# 30it [03:42,  7.16s/it]
#
#
# 31it [03:58,  9.70s/it]
#
#
# 32it [03:58,  6.88s/it]
#
#
# 33it [03:59,  4.88s/it]
#
#
# 34it [04:03,  4.81s/it]
#
#
# 35it [04:04,  3.45s/it]
#
#
# 36it [04:21,  7.51s/it]
#
#
# 37it [04:21,  5.32s/it]
#
#
# 38it [04:21,  3.80s/it]
#
#
# 39it [04:21,  2.74s/it]
#
#
# 40it [04:36,  6.31s/it]
#
#
# 41it [04:43,  6.67s/it]
#
#
# 42it [04:57,  8.70s/it]
#
#
# 43it [04:59,  6.88s/it]
#
#
# 44it [05:00,  4.89s/it]
#
#
# 45it [05:12,  7.21s/it]
#
#
# 46it [05:20,  7.36s/it]
#
#
# 47it [05:25,  6.69s/it]
#
#
# 48it [05:35,  7.66s/it]
#
#
# 49it [05:39,  6.41s/it]
#
#
# 50it [05:41,  5.19s/it]
#
#
# 51it [05:47,  5.50s/it]
#
#
# 52it [05:49,  4.36s/it]
#
#
# 53it [06:04,  7.46s/it]
#
#
# 54it [06:04,  5.30s/it]
#
#
# 55it [06:04,  3.79s/it]
#
#
# 56it [06:05,  2.94s/it]
#
#
# 57it [06:07,  2.79s/it]
#
#
# 58it [06:08,  2.20s/it]
#
#
# 59it [06:25,  6.67s/it]
#
#
# 60it [06:37,  8.27s/it]
#
#
# 61it [06:42,  7.20s/it]
#
#
# 62it [07:00, 10.49s/it]
#
#
# 63it [07:01,  7.42s/it]
#
#
# 64it [07:17, 10.18s/it]
#
#
# 65it [07:17,  7.20s/it]
#
#
# 66it [07:18,  5.12s/it]
#
#
# 67it [07:30,  7.36s/it]
#
#
# 68it [07:33,  5.85s/it]
#
#
# 69it [07:36,  4.98s/it]
#
#
# 70it [07:36,  3.57s/it]
#
#
# 71it [08:03, 10.75s/it]
#
#
# 72it [08:15, 11.08s/it]
#
#
# 73it [08:18,  8.68s/it]
#
#
# 74it [08:22,  7.15s/it]
#
#
# 75it [08:24,  5.77s/it]
#
#
# 76it [08:25,  4.19s/it]
#
#
# 77it [09:15, 18.00s/it]
#
#
# 78it [09:30, 16.98s/it]
#
#
# 79it [09:30, 11.96s/it]
#
#
# 80it [09:40, 11.32s/it]
#
#
# 81it [09:44,  9.35s/it]
#
#
# 82it [09:45,  6.73s/it]
#
#
# 83it [09:45,  4.79s/it]
#
#
# 84it [09:47,  3.83s/it]
#
#
# 85it [09:49,  3.43s/it]
#
#
# 86it [09:56,  4.25s/it]
#
#
# 87it [09:56,  3.07s/it]
#
#
# 88it [10:11,  6.55s/it]
#
#
# 89it [10:21,  7.62s/it]
#
#
# 90it [10:30,  8.23s/it]
#
#
# 91it [10:31,  5.83s/it]
#
#
# 92it [10:33,  4.68s/it]
#
#
# 93it [10:45,  7.07s/it]
#
#
# 94it [10:59,  8.92s/it]
#
#
# 95it [10:59,  6.33s/it]
#
#
# 96it [10:59,  4.50s/it]
#
#
# 97it [11:07,  5.47s/it]
#
#
# 98it [11:26,  9.66s/it]
#
#
# 99it [11:27,  6.92s/it]
#
#
# 100it [11:29,  5.61s/it]
#
#
# 101it [11:37,  6.26s/it]
#
#
# 102it [12:13, 15.13s/it]
#
#
# 103it [12:19, 12.30s/it]
#
#
# 104it [12:20,  8.92s/it]
#
#
# 105it [12:29,  9.10s/it]
#
#
# 106it [12:44, 10.68s/it]
#
#
# 107it [12:49,  9.02s/it]
#
#
# 108it [13:21, 16.16s/it]
#
#
# 109it [13:34, 14.97s/it]
#
#
# 110it [13:41, 12.59s/it]
#
#
# 111it [13:41,  8.90s/it]
#
#
# 112it [13:48,  8.39s/it]
#
#
# 113it [13:56,  8.32s/it]
#
#
# 114it [14:06,  8.82s/it]
#
#
# 115it [14:11,  7.65s/it]
#
#
# 116it [14:16,  6.81s/it]
#
#
# 117it [14:31,  9.23s/it]
#
#
# 118it [14:36,  7.96s/it]
#
#
# 119it [14:38,  6.05s/it]
#
#
# 120it [14:38,  4.31s/it]
#
#
# 121it [14:45,  5.11s/it]
#
#
# 122it [15:00,  8.27s/it]
#
#
# 123it [15:13,  9.44s/it]
#
#
# 124it [15:13,  6.68s/it]
#
#
# 125it [15:13,  4.74s/it]
#
#
# 126it [15:16,  4.12s/it]
#
#
# 127it [15:35,  8.51s/it]
#
#
# 128it [15:35,  6.04s/it]
#
#
# 129it [15:44,  7.13s/it]
#
#
# 130it [15:54,  7.96s/it]
#
#
# 131it [16:09,  9.88s/it]
#
#
# 132it [16:09,  6.99s/it]
#
#
# 133it [16:10,  5.17s/it]
#
#
# 134it [16:15,  5.01s/it]
#
#
# 135it [16:17,  4.30s/it]
#
#
# 136it [16:17,  3.08s/it]
#
#
# 137it [16:18,  2.45s/it]
#
#
# 138it [16:19,  1.86s/it]
#
#
# 139it [16:40,  7.60s/it]
#
#
# 140it [16:42,  6.09s/it]
#
#
# 141it [16:55,  8.06s/it]
#
#
# 142it [17:02,  7.81s/it]
#
#
# 143it [17:07,  6.90s/it]
#
#
# 144it [17:10,  5.60s/it]
#
#
# 145it [17:10,  4.00s/it]
#
#
# 146it [17:11,  3.26s/it]
#
#
# 147it [17:25,  6.50s/it]
#
#
# 148it [17:26,  4.77s/it]
#
#
# 149it [17:27,  3.49s/it]
#
#
# 150it [17:27,  2.53s/it]
#
#
# 151it [17:41,  6.07s/it]
#
#
# 152it [17:46,  5.79s/it]
#
#
# 153it [18:04,  9.28s/it]
#
#
# 154it [18:18, 10.77s/it]
#
#
# 155it [18:23,  8.96s/it]
#
#
# 156it [18:31,  8.57s/it]
#
#
# 157it [18:31,  6.08s/it]
#
#
# 158it [18:33,  5.01s/it]
#
#
# 159it [18:35,  3.93s/it]
#
#
# 160it [19:05, 11.81s/it]
#
#
# 161it [19:08,  9.30s/it]
#
#
# 162it [19:09,  6.58s/it]
#
#
# 163it [19:09,  4.69s/it]
#
#
# 164it [19:16,  5.37s/it]
#
#
# 165it [19:16,  3.83s/it]
#
#
# 166it [19:18,  3.39s/it]
#
#
# 167it [19:23,  3.81s/it]

# %%
articles, timestamps, tickers, prices = remove_empty_tickers(
    articles[:len(filtered_tickers)], timestamps[:len(filtered_tickers)], filtered_tickers, prices)
print(len(articles))
# Out:
# 120

# %%
import pickle

data = {
    'articles': articles,
    'timestamps': timestamps,
    'tickers': tickers,
    'prices': prices
}

pickle.dump(data, open('data.pkl', 'wb'))

# %%
from google.colab import files

files.download('data.pkl')
